# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
img = plt.imread('../input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00301001.png')
plt.imshow(img)

# %%
img1 = plt.imread('../input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00101001.png')
plt.imshow(img1)

# %%
import glob
gen = [glob.glob('../input/handwritten-signatures/Dataset_Signature_Final/Dataset/dataset1/real/*.*'),
       glob.glob('../input/handwritten-signatures/Dataset_Signature_Final/Dataset/dataset2/real/*.*'),
       glob.glob('../input/handwritten-signatures/Dataset_Signature_Final/Dataset/dataset3/real/*.*'),
       glob.glob('../input/handwritten-signatures/Dataset_Signature_Final/Dataset/dataset4/real1/*.*')]
                 
forg = [glob.glob('../input/handwritten-signatures/Dataset_Signature_Final/Dataset/dataset1/forge/*.*'),
        glob.glob('../input/handwritten-signatures/Dataset_Signature_Final/Dataset/dataset2/forge/*.*'),
        glob.glob('../input/handwritten-signatures/Dataset_Signature_Final/Dataset/dataset3/forge/*.*'),
        glob.glob('../input/handwritten-signatures/Dataset_Signature_Final/Dataset/dataset4/forge/*.*')]

# %%
# t_Signature_Final/Dataset/dataset3/forge/*.*'),
#         glob.glob('../input/handwritten-signatures/Dataset_Signature_Final/Dataset/dataset4/forge/*.*')]

# %%
# import glob
# import keras
import cv2

# gen = glob.glob("../input/handwritten-signatures/sample_Signature/sample_Signature/genuine/*.*")
# forg = glob.glob("../input/handwritten-signatures/sample_Signature/sample_Signature/forged/*.*")
# ../input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00101014.png

train_data = []
train_labels = []

test_data = []
test_labels = []

for data in range(len(gen)):
    for i in gen[data]:
        if data == 3:
            image = cv2.imread(i)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (224, 224))
            test_data.append(image)
            test_labels.append(0)
        else:
            image = cv2.imread(i)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (224, 224))
            train_data.append(image)
            train_labels.append(0) #genuine = 0
        
for data in range(len(forg)):
    for j in forg[data]:
        if data == 3:
            image = cv2.imread(j)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (224, 224))
            test_data.append(image)
            test_labels.append(1)
        else:
            image = cv2.imread(j)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (224, 224))
            train_data.append(image)
            train_labels.append(1) #forged = 1

train_data = np.array(train_data)/255.0
train_labels = np.array(train_labels)

test_data = np.array(test_data)/255.0
test_labels = np.array(test_labels)

# %%
train_data.shape
# Out:
# (540, 224, 224, 3)

# %%
from sklearn.utils import shuffle
train_data,train_labels = shuffle(train_data,train_labels)

test_data,test_labels = shuffle(test_data,test_labels)

# %% [markdown]
# # CNN (CONVOLUTION NEURAL NETWORK)

# %% [markdown]
# ### Relu Activation Function

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from keras_preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix as CM
from keras.optimizers import Adam
from keras.optimizers import RMSprop

def relu(x):
    return np.maximum(0, x)

def softmax(x):
    return np.exp(x) / np.sum(np.exp(x), axis=1, keepdims=True)

def objective(x, y):
 return x**2.0 + y**2.0


network = Sequential()

network.add(Conv2D(64,(3,3),input_shape=(224,224,3),activation='relu'))
network.add(MaxPooling2D(3,3))

network.add(Conv2D(32,(3,3),activation='relu'))
network.add(MaxPooling2D(2,2))

network.add(Flatten()) #NX1
network.add(Dense(128,activation = 'relu'))
network.add(Dropout(rate=0.3)) #143

network.add(Dense(2,activation = 'softmax'))

network.compile(optimizer=Adam(lr=0.001),loss="binary_crossentropy",metrics=["accuracy"])
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard
earlyStopping = EarlyStopping(monitor='val_loss',
                              min_delta=0,
                              patience=3,
                              verbose=1)

callback_early_stop_reduceLROnPlateau=[earlyStopping]


EPOCHS = 3
BS = 1
progess = network.fit(train_data,train_labels, batch_size=BS,epochs=EPOCHS, callbacks=callback_early_stop_reduceLROnPlateau,validation_split=.05)
# Out:
# Epoch 1/3
# 513/513 [==============================] - 2s 3ms/step - loss: 0.7130 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.4444
# Epoch 2/3
# 513/513 [==============================] - 1s 3ms/step - loss: 0.6931 - accuracy: 0.5361 - val_loss: 0.6931 - val_accuracy: 0.3704
# Epoch 3/3
# 513/513 [==============================] - 1s 3ms/step - loss: 0.6931 - accuracy: 0.5517 - val_loss: 0.6931 - val_accuracy: 0.3704

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred  #prob of genuine, prob of forged
# Out:
# array([[0.50002486, 0.49997514],
#        [0.49999517, 0.5000048 ],
#        [0.50001836, 0.4999816 ],
#        [0.50001043, 0.4999896 ],
#        [0.50006163, 0.4999384 ],
#        [0.5000322 , 0.49996784],
#        [0.4999759 , 0.5000241 ],
#        [0.50001186, 0.49998814],
#        [0.5000324 , 0.49996758],
#        [0.50002307, 0.49997693],
#        [0.50001043, 0.4999896 ],
#        [0.5000127 , 0.4999873 ],
#        [0.5000353 , 0.4999647 ],
#        [0.49996862, 0.5000314 ],
#        [0.49989936, 0.5001006 ],
#        [0.4999688 , 0.50003123],
#        [0.4999914 , 0.50000864],
#        [0.50001043, 0.4999896 ],
#        [0.5000222 , 0.49997783],
#        [0.5000115 , 0.49998853],
#        [0.50017846, 0.49982157],
#        [0.49981722, 0.50018275],
#        [0.50009644, 0.4999035 ],
#        [0.50001043, 0.4999896 ],
#        [0.49999553, 0.5000045 ],
#        [0.50005734, 0.49994263],
#        [0.50001043, 0.4999896 ],
#        [0.49991077, 0.5000892 ],
#        [0.5000102 , 0.4999898 ],
#        [0.49992105, 0.500079  ],
#        [0.49996755, 0.5000324 ],
#        [0.5000194 , 0.49998063],
#        [0.5005102 , 0.49948978],
#        [0.50003207, 0.49996793],
#        [0.50001043, 0.4999896 ],
#        [0.50001043, 0.4999896 ],
#        [0.5000263 , 0.4999737 ],
#        [0.50001043, 0.4999896 ],
#        [0.5002898 , 0.49971017],
#        [0.50004816, 0.49995184],
#        [0.50030565, 0.49969432],
#        [0.50001043, 0.4999896 ],
#        [0.49984545, 0.50015455],
#        [0.49973455, 0.5002654 ],
#        [0.500043  , 0.49995703],
#        [0.50012743, 0.49987262],
#        [0.50001043, 0.4999896 ],
#        [0.50001043, 0.4999896 ],
#        [0.4999818 , 0.5000182 ],
#        [0.5000582 , 0.49994186],
#        [0.50001043, 0.4999896 ],
#        [0.50002146, 0.49997854],
#        [0.50001043, 0.4999896 ],
#        [0.5000341 , 0.49996594],
#        [0.5000246 , 0.49997535],
#        [0.50001043, 0.4999896 ],
#        [0.50001055, 0.49998942],
#        [0.50001043, 0.4999896 ],
#        [0.50155836, 0.49844167],
#        [0.49993882, 0.50006115],
#        [0.49989027, 0.50010973],
#        [0.49992254, 0.5000775 ],
#        [0.49996772, 0.5000323 ],
#        [0.50002575, 0.49997428],
#        [0.5000397 , 0.49996033],
#        [0.5000387 , 0.4999613 ],
#        [0.50000596, 0.49999407],
#        [0.50001043, 0.4999896 ],
#        [0.5001179 , 0.49988204],
#        [0.50022966, 0.4997703 ],
#        [0.5002813 , 0.4997188 ],
#        [0.5000279 , 0.49997213],
#        [0.5001573 , 0.49984267],
#        [0.50001496, 0.49998504],
#        [0.49988878, 0.5001112 ],
#        [0.500075  , 0.49992505],
#        [0.50001115, 0.49998882],
#        [0.50001043, 0.4999896 ],
#        [0.49990132, 0.50009865],
#        [0.49979362, 0.50020635],
#        [0.50001043, 0.4999896 ],
#        [0.4999606 , 0.5000394 ],
#        [0.50001043, 0.4999896 ],
#        [0.5000183 , 0.49998173],
#        [0.4999685 , 0.5000315 ],
#        [0.5000838 , 0.49991623],
#        [0.50001043, 0.4999896 ],
#        [0.5000178 , 0.49998215],
#        [0.49990052, 0.5000994 ],
#        [0.50001043, 0.4999896 ],
#        [0.4999334 , 0.50006664],
#        [0.5000577 , 0.49994233],
#        [0.4999871 , 0.50001293],
#        [0.5000098 , 0.49999025],
#        [0.5000234 , 0.4999766 ],
#        [0.50001043, 0.4999896 ],
#        [0.50001913, 0.4999809 ],
#        [0.5000477 , 0.49995235],
#        [0.5001589 , 0.49984106],
#        [0.5000813 , 0.49991873],
#        [0.50001043, 0.4999896 ],
#        [0.5000978 , 0.4999022 ],
#        [0.5001097 , 0.4998903 ],
#        [0.50001043, 0.4999896 ],
#        [0.49999547, 0.50000453],
#        [0.50001043, 0.4999896 ],
#        [0.50001043, 0.4999896 ],
#        [0.5000204 , 0.49997965],
#        [0.500054  , 0.499946  ],
#        [0.50005734, 0.4999427 ],
#        [0.49993488, 0.50006515],
#        [0.4999489 , 0.5000511 ],
#        [0.50013745, 0.49986258],
#        [0.50001043, 0.4999896 ],
#        [0.50001043, 0.4999896 ],
#        [0.50004375, 0.49995622],
#        [0.50006276, 0.4999372 ],
#        [0.50001043, 0.4999896 ],
#        [0.50001043, 0.4999896 ],
#        [0.4999754 , 0.5000246 ],
#        [0.50001043, 0.4999896 ],
#        [0.50001043, 0.4999896 ],
#        [0.50001043, 0.4999896 ],
#        [0.50001943, 0.49998054],
#        [0.5006052 , 0.49939477],
#        [0.49999547, 0.50000453],
#        [0.5000157 , 0.4999843 ],
#        [0.5000072 , 0.49999276],
#        [0.50001043, 0.4999896 ],
#        [0.49985218, 0.5001478 ],
#        [0.50028145, 0.49971855],
#        [0.5000686 , 0.49993137],
#        [0.50001043, 0.4999896 ],
#        [0.50031275, 0.49968722],
#        [0.50001043, 0.4999896 ],
#        [0.5000398 , 0.4999602 ],
#        [0.50001043, 0.4999896 ],
#        [0.500439  , 0.49956095],
#        [0.5000084 , 0.49999163],
#        [0.5001479 , 0.49985212],
#        [0.5000805 , 0.49991947],
#        [0.50000733, 0.49999267],
#        [0.50001043, 0.4999896 ],
#        [0.50001043, 0.4999896 ],
#        [0.49982646, 0.50017357],
#        [0.49998853, 0.5000115 ],
#        [0.50002   , 0.49997997],
#        [0.4999953 , 0.5000047 ],
#        [0.49998227, 0.5000177 ],
#        [0.50001365, 0.49998638],
#        [0.49978554, 0.50021446],
#        [0.50001043, 0.4999896 ],
#        [0.5000373 , 0.49996272],
#        [0.5000114 , 0.49998865],
#        [0.5000081 , 0.49999192],
#        [0.5000293 , 0.49997064],
#        [0.5000369 , 0.49996313],
#        [0.49999726, 0.50000274],
#        [0.500011  , 0.499989  ],
#        [0.50000244, 0.4999976 ],
#        [0.49938774, 0.5006123 ],
#        [0.50001043, 0.4999896 ],
#        [0.50000715, 0.49999288],
#        [0.50002325, 0.49997675],
#        [0.5000198 , 0.49998024],
#        [0.5000354 , 0.49996462],
#        [0.50001043, 0.4999896 ],
#        [0.50004077, 0.4999592 ],
#        [0.500014  , 0.49998602],
#        [0.50002503, 0.499975  ],
#        [0.50028646, 0.4997135 ],
#        [0.5000029 , 0.49999708],
#        [0.5004547 , 0.49954528],
#        [0.50000876, 0.4999912 ],
#        [0.5000933 , 0.49990672],
#        [0.50001043, 0.4999896 ],
#        [0.50001043, 0.4999896 ],
#        [0.50010693, 0.49989307],
#        [0.5000709 , 0.4999291 ],
#        [0.5000095 , 0.49999055]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.46111111111111114

# %% [markdown]
# ### SIGMOID ACTIVATION FUNCTION

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from keras_preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix as CM
from keras.optimizers import Adam
from keras.optimizers import RMSprop

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def softmax(x):
    return np.exp(x) / np.sum(np.exp(x), axis=1, keepdims=True)

network = Sequential()

network.add(Conv2D(64,(3,3),input_shape=(224,224,3),activation='sigmoid'))
network.add(MaxPooling2D(3,3))

network.add(Conv2D(32,(3,3),activation='sigmoid'))
network.add(MaxPooling2D(2,2))

network.add(Flatten()) #NX1
network.add(Dense(128,activation = 'sigmoid'))
network.add(Dropout(rate=0.3)) #143

network.add(Dense(2,activation = 'softmax'))

network.compile(optimizer=Adam(lr=0.001),loss="binary_crossentropy",metrics=["accuracy"])
network.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 222, 222, 64)      1792
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 72, 72, 32)        18464
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               5308544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard
earlyStopping = EarlyStopping(monitor='val_loss',
                              min_delta=0,
                              patience=3,
                              verbose=1)

callback_early_stop_reduceLROnPlateau=[earlyStopping]


EPOCHS = 3
BS = 1
progess = network.fit(train_data,train_labels, batch_size=BS,epochs=EPOCHS, callbacks=callback_early_stop_reduceLROnPlateau,validation_split=.05)
# Out:
# Epoch 1/3
# 513/513 [==============================] - 2s 3ms/step - loss: 0.7784 - accuracy: 0.4717 - val_loss: 0.6933 - val_accuracy: 0.3704
# Epoch 2/3
# 513/513 [==============================] - 2s 3ms/step - loss: 0.7172 - accuracy: 0.4912 - val_loss: 0.6935 - val_accuracy: 0.3704
# Epoch 3/3
# 513/513 [==============================] - 2s 3ms/step - loss: 0.7006 - accuracy: 0.4503 - val_loss: 0.6935 - val_accuracy: 0.6296

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred  #prob of genuine, prob of forged
# Out:
# array([[0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485],
#        [0.4863515, 0.5136485]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.5

# %% [markdown]
# ### TANH ACTIVATION FUNCTION

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from keras_preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix as CM
from keras.optimizers import Adam
from keras.optimizers import RMSprop

def tanh(x):
    return np.tanh(x)

def softmax(x):
    return np.exp(x) / np.sum(np.exp(x), axis=1, keepdims=True)

network = Sequential()

network.add(Conv2D(64,(3,3),input_shape=(224,224,3),activation='tanh'))
network.add(MaxPooling2D(3,3))

network.add(Conv2D(32,(3,3),activation='tanh'))
network.add(MaxPooling2D(2,2))

network.add(Flatten()) #NX1
network.add(Dense(128,activation = 'tanh'))
network.add(Dropout(rate=0.3)) #143

network.add(Dense(2,activation = 'softmax'))

network.compile(optimizer=Adam(lr=0.001),loss="binary_crossentropy",metrics=["accuracy"])
network.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 222, 222, 64)      1792
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 32)        18464
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               5308544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard
earlyStopping = EarlyStopping(monitor='val_loss',
                              min_delta=0,
                              patience=3,
                              verbose=1)

callback_early_stop_reduceLROnPlateau=[earlyStopping]


EPOCHS = 4
BS = 1
progess = network.fit(train_data,train_labels, batch_size=BS,epochs=EPOCHS, callbacks=callback_early_stop_reduceLROnPlateau,validation_split=.05)
# Out:
# Epoch 1/4
# 513/513 [==============================] - 2s 4ms/step - loss: 0.9103 - accuracy: 0.4756 - val_loss: 0.7009 - val_accuracy: 0.6296
# Epoch 2/4
# 513/513 [==============================] - 2s 3ms/step - loss: 0.7566 - accuracy: 0.5049 - val_loss: 0.7116 - val_accuracy: 0.3704
# Epoch 3/4
# 513/513 [==============================] - 2s 3ms/step - loss: 0.7231 - accuracy: 0.4600 - val_loss: 0.6956 - val_accuracy: 0.6296
# Epoch 4/4
# 513/513 [==============================] - 2s 4ms/step - loss: 0.7055 - accuracy: 0.4932 - val_loss: 0.6951 - val_accuracy: 0.6296

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred
# Out:
# array([[0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.5

# %% [markdown]
# <hr>

# %% [markdown]
# # SIAMESE NEURAL NETWORK

# %% [markdown]
# ## DISTANCES USED
#
# * Euclidean Distance
# * Manhattan Distance
# * Hamming Distance
# * Minkowski Distance

# %% [markdown]
# ## **1. Using Euclidean Distance**

# %% [markdown]
# ## SIGMOID ACTIVATION FUNCTION

# %%
from sklearn.utils import shuffle
train_data,train_labels = shuffle(train_data,train_labels)

test_data,test_labels = shuffle(test_data,test_labels)

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, Dropout
import keras.backend as K

def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu')(input)
    x = MaxPooling2D(3, 3)(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D(2, 2)(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(rate=0.3)(x)
    return Model(input, x)

input_shape = (224, 224, 3)
base_network = create_base_network(input_shape)

input1 = Input(shape=input_shape)
input2 = Input(shape=input_shape)

output1 = base_network(input1)
output2 = base_network(input2)

distance = Lambda(lambda x: K.abs(x[0] - x[1]))([output1, output2])
prediction = Dense(2, activation='softmax')(distance)

siamese_network = Model(inputs=[input1, input2], outputs=prediction)
siamese_network.compile(optimizer=Adam(lr=0.001), loss="binary_crossentropy", metrics=["accuracy"])
siamese_network.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# functional_1 (Functional)       (None, 128)          5328800     input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128)          0           functional_1[0][0]
#                                                                  functional_1[1][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            258         lambda[0][0]
# ==================================================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda
from keras.models import Model
from keras import backend as K
import numpy as np
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, concatenate


# define input shape for the network
input_shape = (224, 224, 3)

# define the left and right input tensors
left_input = Input(input_shape)
right_input = Input(input_shape)

#sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# define the convolutional layers
convnet = Sequential()
convnet.add(Conv2D(64,(3,3),input_shape=input_shape,activation='sigmoid'))
convnet.add(MaxPooling2D(3,3))
convnet.add(Conv2D(32,(3,3),activation='sigmoid'))
convnet.add(MaxPooling2D(2,2))
convnet.add(Flatten())
convnet.add(Dense(128,activation = 'sigmoid'))
convnet.add(Dropout(rate=0.3))

# create the left and right branches of the network
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)

# define the distance metric function
def euclidean_distance(vectors):
    (featsA, featsB) = vectors
    sumSquared = K.sum(K.square(featsA - featsB), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sumSquared, K.epsilon()))


# define siamese model
def build_siamese_model(input_shape):
    left_input = Input(input_shape)
    right_input = Input(input_shape)

    model = Sequential()
    model.add(Conv2D(64, (3, 3), activation='sigmoid', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(32, (3, 3), activation='sigmoid'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='sigmoid'))
    
    encoded_l = model(left_input)
    encoded_r = model(right_input)

    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])

    prediction = Dense(1, activation='sigmoid')(L1_distance)
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

    return siamese_net

# define the output layer
distance = Lambda(euclidean_distance)([encoded_l, encoded_r])
outputs = Dense(1, activation="sigmoid")(distance)

# create the siamese network model
model = Model(inputs=[left_input, right_input], outputs=outputs)

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# prepare the input data
train_data1 = np.random.rand(100, 224, 224, 3)
train_data2 = np.random.rand(100, 224, 224, 3)
train_labels = np.random.randint(2, size=(100, 1))

# train the model
history = model.fit([train_data1, train_data2], train_labels, batch_size=16, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 73ms/step - loss: 0.7117 - accuracy: 0.4375 - val_loss: 0.6939 - val_accuracy: 0.3000
# Epoch 2/10
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7109 - accuracy: 0.4375 - val_loss: 0.6945 - val_accuracy: 0.3000
# Epoch 3/10
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7097 - accuracy: 0.4375 - val_loss: 0.6952 - val_accuracy: 0.3000
# Epoch 4/10
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7069 - accuracy: 0.4375 - val_loss: 0.6958 - val_accuracy: 0.3000
# Epoch 5/10
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7039 - accuracy: 0.4375 - val_loss: 0.6965 - val_accuracy: 0.3000
# Epoch 6/10
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7014 - accuracy: 0.4375 - val_loss: 0.6970 - val_accuracy: 0.3000
# Epoch 7/10
# 5/5 [==============================] - 0s 35ms/step - loss: 0.6999 - accuracy: 0.4375 - val_loss: 0.6976 - val_accuracy: 0.3000
# Epoch 8/10
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6984 - accuracy: 0.4375 - val_loss: 0.6982 - val_accuracy: 0.3000
# Epoch 9/10
# 5/5 [==============================] - 0s 36ms/step - loss: 0.6954 - accuracy: 0.4375 - val_loss: 0.6986 - val_accuracy: 0.3000
# Epoch 10/10
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6956 - accuracy: 0.4375 - val_loss: 0.6992 - val_accuracy: 0.3000

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred
# Out:
# array([[0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.5

# %% [markdown]
# ## RELU ACTIVATION FUNCTION

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, Dropout
import keras.backend as K

def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu')(input)
    x = MaxPooling2D(3, 3)(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D(2, 2)(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(rate=0.3)(x)
    return Model(input, x)

input_shape = (224, 224, 3)
base_network = create_base_network(input_shape)

input1 = Input(shape=input_shape)
input2 = Input(shape=input_shape)

output1 = base_network(input1)
output2 = base_network(input2)

distance = Lambda(lambda x: K.abs(x[0] - x[1]))([output1, output2])
prediction = Dense(2, activation='softmax')(distance)

siamese_network = Model(inputs=[input1, input2], outputs=prediction)
siamese_network.compile(optimizer=Adam(lr=0.001), loss="binary_crossentropy", metrics=["accuracy"])
siamese_network.summary()
# Out:
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# functional_7 (Functional)       (None, 128)          5328800     input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 128)          0           functional_7[0][0]
#                                                                  functional_7[1][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            258         lambda_2[0][0]
# ==================================================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda
from keras.models import Model
from keras import backend as K
import numpy as np
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, concatenate


# define input shape for the network
input_shape = (224, 224, 3)

# define the left and right input tensors
left_input = Input(input_shape)
right_input = Input(input_shape)

#sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return max(0, x)

# define the convolutional layers
convnet = Sequential()
convnet.add(Conv2D(64,(3,3),input_shape=input_shape,activation='relu'))
convnet.add(MaxPooling2D(3,3))
convnet.add(Conv2D(32,(3,3),activation='relu'))
convnet.add(MaxPooling2D(2,2))
convnet.add(Flatten())
convnet.add(Dense(128,activation = 'relu'))
convnet.add(Dropout(rate=0.3))

# create the left and right branches of the network
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)

# define the distance metric function
def euclidean_distance(vectors):
    (featsA, featsB) = vectors
    sumSquared = K.sum(K.square(featsA - featsB), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sumSquared, K.epsilon()))


# define siamese model
def build_siamese_model(input_shape):
    left_input = Input(input_shape)
    right_input = Input(input_shape)

    model = Sequential()
    model.add(Conv2D(64, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    
    encoded_l = model(left_input)
    encoded_r = model(right_input)

    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])

    prediction = Dense(1, activation='relu')(L1_distance)
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

    return siamese_net

# define the output layer
distance = Lambda(euclidean_distance)([encoded_l, encoded_r])
outputs = Dense(1, activation="relu")(distance)

# create the siamese network model
model = Model(inputs=[left_input, right_input], outputs=outputs)

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# prepare the input data
train_data1 = np.random.rand(100, 224, 224, 3)
train_data2 = np.random.rand(100, 224, 224, 3)
train_labels = np.random.randint(2, size=(100, 1))

# train the model
history = model.fit([train_data1, train_data2], train_labels, batch_size=16, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 73ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500
# Epoch 2/10
# 5/5 [==============================] - 0s 31ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500
# Epoch 3/10
# 5/5 [==============================] - 0s 30ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500
# Epoch 4/10
# 5/5 [==============================] - 0s 29ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500
# Epoch 5/10
# 5/5 [==============================] - 0s 29ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500
# Epoch 6/10
# 5/5 [==============================] - 0s 31ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500
# Epoch 7/10
# 5/5 [==============================] - 0s 30ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500
# Epoch 8/10
# 5/5 [==============================] - 0s 32ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500
# Epoch 9/10
# 5/5 [==============================] - 0s 32ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500
# Epoch 10/10
# 5/5 [==============================] - 0s 29ms/step - loss: 6.8622 - accuracy: 0.5500 - val_loss: 1.0343 - val_accuracy: 0.4500

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred
# Out:
# array([[0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.5

# %% [markdown]
# ## **2. Using Manhattan Distance**

# %% [markdown]
# ## Using RELU Activation Function

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, Dropout
import keras.backend as K

def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu')(input)
    x = MaxPooling2D(3, 3)(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D(2, 2)(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(rate=0.3)(x)
    return Model(input, x)

input_shape = (224, 224, 3)
base_network = create_base_network(input_shape)

input1 = Input(shape=input_shape)
input2 = Input(shape=input_shape)

output1 = base_network(input1)
output2 = base_network(input2)

distance = Lambda(lambda x: K.abs(x[0] - x[1]))([output1, output2])
prediction = Dense(2, activation='softmax')(distance)

siamese_network = Model(inputs=[input1, input2], outputs=prediction)
siamese_network.compile(optimizer=Adam(lr=0.001), loss="binary_crossentropy", metrics=["accuracy"])
siamese_network.summary()
# Out:
# Model: "functional_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# functional_13 (Functional)      (None, 128)          5328800     input_12[0][0]
#                                                                  input_13[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128)          0           functional_13[0][0]
#                                                                  functional_13[1][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 2)            258         lambda_4[0][0]
# ==================================================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda
from keras.models import Model
from keras import backend as K
import numpy as np
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, concatenate


# define input shape for the network
input_shape = (224, 224, 3)

# define the left and right input tensors
left_input = Input(input_shape)
right_input = Input(input_shape)

#sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return max(0, x)

# define the convolutional layers
convnet = Sequential()
convnet.add(Conv2D(64,(3,3),input_shape=input_shape,activation='relu'))
convnet.add(MaxPooling2D(3,3))
convnet.add(Conv2D(32,(3,3),activation='relu'))
convnet.add(MaxPooling2D(2,2))
convnet.add(Flatten())
convnet.add(Dense(128,activation = 'relu'))
convnet.add(Dropout(rate=0.3))

# create the left and right branches of the network
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)

# define the distance metric function
def manhattan_distance(vectors):
    (featsA, featsB) = vectors
    return K.sum(K.abs(featsA - featsB), axis=1, keepdims=True)


# define siamese model
def build_siamese_model(input_shape):
    left_input = Input(input_shape)
    right_input = Input(input_shape)

    model = Sequential()
    model.add(Conv2D(64, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    
    encoded_l = model(left_input)
    encoded_r = model(right_input)

    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])

    prediction = Dense(1, activation='relu')(L1_distance)
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

    return siamese_net

# define the output layer
distance = Lambda(manhattan_distance)([encoded_l, encoded_r])
outputs = Dense(1, activation="relu")(distance)

# create the siamese network model
model = Model(inputs=[left_input, right_input], outputs=outputs)

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# prepare the input data
train_data1 = np.random.rand(100, 224, 224, 3)
train_data2 = np.random.rand(100, 224, 224, 3)
train_labels = np.random.randint(2, size=(100, 1))

# train the model
history = model.fit([train_data1, train_data2], train_labels, batch_size=16, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 61ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 2/10
# 5/5 [==============================] - 0s 31ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 3/10
# 5/5 [==============================] - 0s 29ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 4/10
# 5/5 [==============================] - 0s 30ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 5/10
# 5/5 [==============================] - 0s 32ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 6/10
# 5/5 [==============================] - 0s 30ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 7/10
# 5/5 [==============================] - 0s 31ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 8/10
# 5/5 [==============================] - 0s 29ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 9/10
# 5/5 [==============================] - 0s 29ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 10/10
# 5/5 [==============================] - 0s 29ms/step - loss: 9.0622 - accuracy: 0.4125 - val_loss: 7.7125 - val_accuracy: 0.5000

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred
# Out:
# array([[0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.5

# %% [markdown]
# ## Using SIGMOID Activation Function

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, Dropout
import keras.backend as K

def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='sigmoid')(input)
    x = MaxPooling2D(3, 3)(x)
    x = Conv2D(32, (3, 3), activation='sigmoid')(x)
    x = MaxPooling2D(2, 2)(x)
    x = Flatten()(x)
    x = Dense(128, activation='sigmoid')(x)
    x = Dropout(rate=0.3)(x)
    return Model(input, x)

input_shape = (224, 224, 3)
base_network = create_base_network(input_shape)

input1 = Input(shape=input_shape)
input2 = Input(shape=input_shape)

output1 = base_network(input1)
output2 = base_network(input2)

distance = Lambda(lambda x: K.abs(x[0] - x[1]))([output1, output2])
prediction = Dense(2, activation='softmax')(distance)

siamese_network = Model(inputs=[input1, input2], outputs=prediction)
siamese_network.compile(optimizer=Adam(lr=0.001), loss="binary_crossentropy", metrics=["accuracy"])
siamese_network.summary()
# Out:
# Model: "functional_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_17 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# functional_19 (Functional)      (None, 128)          5328800     input_17[0][0]
#                                                                  input_18[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 128)          0           functional_19[0][0]
#                                                                  functional_19[1][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 2)            258         lambda_6[0][0]
# ==================================================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda
from keras.models import Model
from keras import backend as K
import numpy as np
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, concatenate


# define input shape for the network
input_shape = (224, 224, 3)

# define the left and right input tensors
left_input = Input(input_shape)
right_input = Input(input_shape)

#sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return max(0, x)

# define the convolutional layers
convnet = Sequential()
convnet.add(Conv2D(64,(3,3),input_shape=input_shape,activation='sigmoid'))
convnet.add(MaxPooling2D(3,3))
convnet.add(Conv2D(32,(3,3),activation='sigmoid'))
convnet.add(MaxPooling2D(2,2))
convnet.add(Flatten())
convnet.add(Dense(128,activation = 'sigmoid'))
convnet.add(Dropout(rate=0.3))

# create the left and right branches of the network
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)

# define the distance metric function
def manhattan_distance(vectors):
    (featsA, featsB) = vectors
    return K.sum(K.abs(featsA - featsB), axis=1, keepdims=True)


# define siamese model
def build_siamese_model(input_shape):
    left_input = Input(input_shape)
    right_input = Input(input_shape)

    model = Sequential()
    model.add(Conv2D(64, (3, 3), activation='sigmoid', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(32, (3, 3), activation='sigmoid'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='sigmoid'))
    
    encoded_l = model(left_input)
    encoded_r = model(right_input)

    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])

    prediction = Dense(1, activation='sigmoid')(L1_distance)
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

    return siamese_net

# define the output layer
distance = Lambda(manhattan_distance)([encoded_l, encoded_r])
outputs = Dense(1, activation="sigmoid")(distance)

# create the siamese network model
model = Model(inputs=[left_input, right_input], outputs=outputs)

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# prepare the input data
train_data1 = np.random.rand(100, 224, 224, 3)
train_data2 = np.random.rand(100, 224, 224, 3)
train_labels = np.random.randint(2, size=(100, 1))

# train the model
history = model.fit([train_data1, train_data2], train_labels, batch_size=16, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 62ms/step - loss: 3.4440 - accuracy: 0.4000 - val_loss: 0.6937 - val_accuracy: 0.3500
# Epoch 2/10
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7134 - accuracy: 0.5500 - val_loss: 0.6940 - val_accuracy: 0.3500
# Epoch 3/10
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6741 - accuracy: 0.6375 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 4/10
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7396 - accuracy: 0.4625 - val_loss: 0.6947 - val_accuracy: 0.3500
# Epoch 5/10
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7760 - accuracy: 0.4000 - val_loss: 0.6951 - val_accuracy: 0.3500
# Epoch 6/10
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7371 - accuracy: 0.4750 - val_loss: 0.6955 - val_accuracy: 0.3500
# Epoch 7/10
# 5/5 [==============================] - 0s 44ms/step - loss: 0.7370 - accuracy: 0.4625 - val_loss: 0.6959 - val_accuracy: 0.3500
# Epoch 8/10
# 5/5 [==============================] - 0s 38ms/step - loss: 0.7076 - accuracy: 0.5625 - val_loss: 0.6963 - val_accuracy: 0.3500
# Epoch 9/10
# 5/5 [==============================] - 0s 37ms/step - loss: 0.7584 - accuracy: 0.4375 - val_loss: 0.6967 - val_accuracy: 0.3500
# Epoch 10/10
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7259 - accuracy: 0.5000 - val_loss: 0.6971 - val_accuracy: 0.3500

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred
# Out:
# array([[0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
# from sklearn.metrics import precision_recall_fscore_support
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.5

# %%
from sklearn.metrics import precision_recall_fscore_support

# calculate precision, recall, and F1 score
precision, recall, f1score, _ = precision_recall_fscore_support(test_labels, pred.argmax(axis=1), average='weighted')

print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1score)
# Out:
# Precision:  0.25
# Recall:  0.5
# F1 Score:  0.3333333333333333
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## **3. Using Hamming Distance**

# %% [markdown]
# ## Using RELU Activation Function

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, Dropout
import keras.backend as K

def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu')(input)
    x = MaxPooling2D(3, 3)(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D(2, 2)(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(rate=0.3)(x)
    return Model(input, x)

input_shape = (224, 224, 3)
base_network = create_base_network(input_shape)

input1 = Input(shape=input_shape)
input2 = Input(shape=input_shape)

output1 = base_network(input1)
output2 = base_network(input2)

distance = Lambda(lambda x: K.abs(x[0] - x[1]))([output1, output2])
prediction = Dense(2, activation='softmax')(distance)

siamese_network = Model(inputs=[input1, input2], outputs=prediction)
siamese_network.compile(optimizer=Adam(lr=0.001), loss="binary_crossentropy", metrics=["accuracy"])
siamese_network.summary()
# Out:
# Model: "functional_27"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_22 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_23 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# functional_25 (Functional)      (None, 128)          5328800     input_22[0][0]
#                                                                  input_23[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 128)          0           functional_25[0][0]
#                                                                  functional_25[1][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 2)            258         lambda_8[0][0]
# ==================================================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda
from keras.models import Model
from keras import backend as K
import numpy as np
import binascii
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)


# define input shape for the network
input_shape = (224, 224, 3)

# define the left and right input tensors
left_input = Input(input_shape)
right_input = Input(input_shape)

# define the convolutional layers
convnet = Sequential()
convnet.add(Conv2D(64,(3,3),input_shape=input_shape,activation='relu'))
convnet.add(MaxPooling2D(3,3))
convnet.add(Conv2D(32,(3,3),activation='relu'))
convnet.add(MaxPooling2D(2,2))
convnet.add(Flatten())
convnet.add(Dense(128,activation = 'relu'))
convnet.add(Dropout(rate=0.3))

# create the left and right branches of the network
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)

@tf.function
def hamming_distance(vectors):
    (featsA, featsB) = vectors
    return K.sum(K.abs(featsA - featsB), axis=1, keepdims=True)

# define the output layer
distance = Lambda(hamming_distance)([encoded_l, encoded_r])
outputs = Dense(1, activation="relu")(distance)

# create the siamese network model
model = Model(inputs=[left_input, right_input], outputs=outputs)

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# prepare the input data
train_data1 = np.random.rand(100, 224, 224, 3)
train_data2 = np.random.rand(100, 224, 224, 3)
train_labels = np.random.randint(2, size=(100, 1))

# train the model
history = model.fit([train_data1, train_data2], train_labels, batch_size=16, epochs=10, validation_split=0.2)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:3350: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "
# Epoch 1/10
# 5/5 [==============================] - 0s 66ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000
# Epoch 2/10
# 5/5 [==============================] - 0s 60ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000
# Epoch 3/10
# 5/5 [==============================] - 0s 60ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000
# Epoch 4/10
# 5/5 [==============================] - 0s 61ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000
# Epoch 5/10
# 5/5 [==============================] - 0s 60ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000
# Epoch 6/10
# 5/5 [==============================] - 0s 61ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000
# Epoch 7/10
# 5/5 [==============================] - 0s 60ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000
# Epoch 8/10
# 5/5 [==============================] - 0s 61ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000
# Epoch 9/10
# 5/5 [==============================] - 0s 60ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000
# Epoch 10/10
# 5/5 [==============================] - 0s 60ms/step - loss: 8.2416 - accuracy: 0.4625 - val_loss: 5.8634 - val_accuracy: 0.5000

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred
# Out:
# array([[0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.5

# %% [markdown]
# ## Using SIGMOID Activation Function

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, Dropout
import keras.backend as K

def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu')(input)
    x = MaxPooling2D(3, 3)(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D(2, 2)(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(rate=0.3)(x)
    return Model(input, x)

input_shape = (224, 224, 3)
base_network = create_base_network(input_shape)

input1 = Input(shape=input_shape)
input2 = Input(shape=input_shape)

output1 = base_network(input1)
output2 = base_network(input2)

distance = Lambda(lambda x: K.abs(x[0] - x[1]))([output1, output2])
prediction = Dense(2, activation='softmax')(distance)

siamese_network = Model(inputs=[input1, input2], outputs=prediction)
siamese_network.compile(optimizer=Adam(lr=0.001), loss="binary_crossentropy", metrics=["accuracy"])
siamese_network.summary()
# Out:
# Model: "functional_33"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_27 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# functional_31 (Functional)      (None, 128)          5328800     input_27[0][0]
#                                                                  input_28[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 128)          0           functional_31[0][0]
#                                                                  functional_31[1][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 2)            258         lambda_10[0][0]
# ==================================================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda
from keras.models import Model
from keras import backend as K
import numpy as np
import binascii
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)


# define input shape for the network
input_shape = (224, 224, 3)

# define the left and right input tensors
left_input = Input(input_shape)
right_input = Input(input_shape)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return max(0, x)

# define the convolutional layers
convnet = Sequential()
convnet.add(Conv2D(64,(3,3),input_shape=input_shape,activation='sigmoid'))
convnet.add(MaxPooling2D(3,3))
convnet.add(Conv2D(32,(3,3),activation='sigmoid'))
convnet.add(MaxPooling2D(2,2))
convnet.add(Flatten())
convnet.add(Dense(128,activation = 'sigmoid'))
convnet.add(Dropout(rate=0.3))

# create the left and right branches of the network
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)

@tf.function
def hamming_distance(vectors):
    (featsA, featsB) = vectors
    return K.sum(K.abs(featsA - featsB), axis=1, keepdims=True)

# define the output layer
distance = Lambda(hamming_distance)([encoded_l, encoded_r])
outputs = Dense(1, activation="relu")(distance)

# create the siamese network model
model = Model(inputs=[left_input, right_input], outputs=outputs)

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# prepare the input data
train_data1 = np.random.rand(100, 224, 224, 3)
train_data2 = np.random.rand(100, 224, 224, 3)
train_labels = np.random.randint(2, size=(100, 1))

# train the model
history = model.fit([train_data1, train_data2], train_labels, batch_size=16, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 67ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000
# Epoch 2/10
# 5/5 [==============================] - 0s 62ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000
# Epoch 3/10
# 5/5 [==============================] - 0s 62ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000
# Epoch 4/10
# 5/5 [==============================] - 0s 62ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000
# Epoch 5/10
# 5/5 [==============================] - 0s 62ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000
# Epoch 6/10
# 5/5 [==============================] - 0s 61ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000
# Epoch 7/10
# 5/5 [==============================] - 0s 61ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000
# Epoch 8/10
# 5/5 [==============================] - 0s 62ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000
# Epoch 9/10
# 5/5 [==============================] - 0s 61ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000
# Epoch 10/10
# 5/5 [==============================] - 0s 60ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.5000

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred
# Out:
# array([[0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.5

# %% [markdown]
# ## **4. Using Minkowski Distance**

# %% [markdown]
# ## Using RELU Activation Function

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, Dropout
import keras.backend as K

def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu')(input)
    x = MaxPooling2D(3, 3)(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D(2, 2)(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(rate=0.3)(x)
    return Model(input, x)

input_shape = (224, 224, 3)
base_network = create_base_network(input_shape)

input1 = Input(shape=input_shape)
input2 = Input(shape=input_shape)

output1 = base_network(input1)
output2 = base_network(input2)

distance = Lambda(lambda x: K.abs(x[0] - x[1]))([output1, output2])
prediction = Dense(2, activation='softmax')(distance)

siamese_network = Model(inputs=[input1, input2], outputs=prediction)
siamese_network.compile(optimizer=Adam(lr=0.001), loss="binary_crossentropy", metrics=["accuracy"])
siamese_network.summary()
# Out:
# Model: "functional_39"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_32 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_33 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# functional_37 (Functional)      (None, 128)          5328800     input_32[0][0]
#                                                                  input_33[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 128)          0           functional_37[0][0]
#                                                                  functional_37[1][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 2)            258         lambda_12[0][0]
# ==================================================================================================
# Total params: 5,329,058
# Trainable params: 5,329,058
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda
from keras.models import Model
from keras import backend as K
import numpy as np

# Define the input shape for the network
input_shape = (224, 224, 3)

# Define the left and right input tensors
left_input = Input(input_shape)
right_input = Input(input_shape)

# Define the convolutional layers
convnet = Sequential()
convnet.add(Conv2D(64,(3,3),input_shape=input_shape,activation='relu'))
convnet.add(MaxPooling2D(3,3))
convnet.add(Conv2D(32,(3,3),activation='relu'))
convnet.add(MaxPooling2D(2,2))
convnet.add(Flatten())
convnet.add(Dense(128,activation = 'relu'))
convnet.add(Dropout(rate=0.3))

# Create the left and right branches of the network
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)

# Define the distance metric function using Minkowski distance
def minkowski_distance(vectors):
    (featsA, featsB) = vectors
    diff = K.abs(featsA - featsB)
    return K.sum(K.pow(diff, 3), axis=-1, keepdims=True)

# Define the output layer
distance = Lambda(minkowski_distance)([encoded_l, encoded_r])
outputs = Dense(1, activation="relu")(distance)

# Create the siamese network model
model = Model(inputs=[left_input, right_input], outputs=outputs)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Prepare the input data
train_data1 = np.random.rand(100, 224, 224, 3)
train_data2 = np.random.rand(100, 224, 224, 3)
train_labels = np.random.randint(2, size=(100, 1))

# Train the model
history = model.fit([train_data1, train_data2], train_labels, batch_size=16, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 68ms/step - loss: 6.5166 - accuracy: 0.5750 - val_loss: 2.0693 - val_accuracy: 0.4500
# Epoch 2/10
# 5/5 [==============================] - 0s 61ms/step - loss: 6.5166 - accuracy: 0.5750 - val_loss: 2.0693 - val_accuracy: 0.4500
# Epoch 3/10
# 5/5 [==============================] - 0s 61ms/step - loss: 6.5166 - accuracy: 0.5750 - val_loss: 2.0693 - val_accuracy: 0.4500
# Epoch 4/10
# 5/5 [==============================] - 0s 62ms/step - loss: 6.5166 - accuracy: 0.5750 - val_loss: 2.0693 - val_accuracy: 0.4500
# Epoch 5/10
# 5/5 [==============================] - 0s 61ms/step - loss: 6.5182 - accuracy: 0.5750 - val_loss: 1.9966 - val_accuracy: 0.4500
# Epoch 6/10
# 5/5 [==============================] - 0s 60ms/step - loss: 6.5166 - accuracy: 0.5750 - val_loss: 1.7897 - val_accuracy: 0.4500
# Epoch 7/10
# 5/5 [==============================] - 0s 60ms/step - loss: 6.5166 - accuracy: 0.5750 - val_loss: 1.5851 - val_accuracy: 0.4500
# Epoch 8/10
# 5/5 [==============================] - 0s 60ms/step - loss: 6.5166 - accuracy: 0.5750 - val_loss: 1.4318 - val_accuracy: 0.5000
# Epoch 9/10
# 5/5 [==============================] - 0s 60ms/step - loss: 6.5166 - accuracy: 0.5750 - val_loss: 1.3360 - val_accuracy: 0.5000
# Epoch 10/10
# 5/5 [==============================] - 0s 59ms/step - loss: 6.5166 - accuracy: 0.5750 - val_loss: 1.2880 - val_accuracy: 0.4500

# %%
acc = progess.history['accuracy']
val_acc = progess.history['val_accuracy']
loss = progess.history['loss']
val_loss = progess.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
 
plt.figure()

# %%
pred = network.predict(test_data)

# %%
pred
# Out:
# array([[0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ],
#        [0.46889073, 0.5311093 ]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred.argmax(axis=1), test_labels)
# Out:
# 0.5

# %% [markdown]
# # USING CEDAR DATASET

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/README.txt.txt
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00503015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00401024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02502010.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01104012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00103030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00101014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01101016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02304008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00505022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00103014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00105028.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-03305006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00104029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02505009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00105026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00405024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00402003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00104014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00104025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00404013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02503010.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00705011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00403013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00703023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01102012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00103019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00704023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00104027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00404003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00102025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00102030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01202021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00402024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02504010.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00401013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02301008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00405003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-03303006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-03302006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00301009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00405013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00302009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00103026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01701020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00304002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00504022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00302002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-08803004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00102028.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00304009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00303001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00305001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00403007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00103029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-03304006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02501010.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01303017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00304001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00702011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00101029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02305008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00702023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00105019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00304018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00105014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-08805004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00102029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01305017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00101019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00302001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00102014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01103012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00302018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00301001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00501015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00705023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00101027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01201021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00301018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01105012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00401003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00101028.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01703020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-08802004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01301017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01102016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00302005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-03301006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00103025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00104028.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01702020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00501022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00701023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00105030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00504015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02306008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01205021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00105027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-08801004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00703011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00403024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00404024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00305002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01704020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00301005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00305005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00102027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00104030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-08804004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00101026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01103016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00503022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01101012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01705020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01203021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00105029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00505015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00301002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00105025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00104019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00304005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00101025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00403003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00303002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00502022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00103027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00401007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00303009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00101030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00405007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01104016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00102019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00704011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01105016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00502015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00305009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01302017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00303005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00104026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00305018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-02303008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00402007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00701011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01204021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-01304017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00404007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00303018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00103028.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00402013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/forged/NFI-00102026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01104011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00101001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00504005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00801008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01103011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00405004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01102011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00305003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00803008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01903019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02705027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00203002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01601016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00505005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01405014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01604016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01301013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01801018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02401024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01002010.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02904029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01001010.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02304023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01704017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01702017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00901009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02901029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02103021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01204012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02903029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02703027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02202022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01502015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02302023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01504015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01202012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00903009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00804008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01105011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00604006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02604026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01005010.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00702007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00701007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00303003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00304003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02105021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01404014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01901019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00605006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00502005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02601026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01501015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02503025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01905019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00703007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01003010.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02701027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01904019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02201022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02305023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01302013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02205022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01701017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00602006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01605016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02801028.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00301003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00404004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01004010.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02905029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02501025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01201012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02004020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02002020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00401004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01505015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02403024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01602016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02005020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01603016.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01503015.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00503005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01205012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01305013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00601006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00704007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01804018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00205002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00103001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01805018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01802018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00802008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00202002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00105001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00102001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02802028.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02805028.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00705007.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01303013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-03005030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02003020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00302003.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00904009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-03003030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01902019.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01304013.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02402024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02504025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01203012.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02303023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00402004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02603026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00104001.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01705017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02101021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02502025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02203022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02704027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02001020.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-03001030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01101011.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00805008.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02702027.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01703017.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01803018.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01401014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-03004030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02404024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02605026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02405024.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02102021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00905009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-03002030.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01403014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02104021.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02505025.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02204022.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00201002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-01402014.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00204002.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00902009.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00603006.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00403004.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-00501005.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02902029.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02602026.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02301023.png
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02803028.PNG
# /kaggle/input/handwritten-signatures/sample_Signature/sample_Signature/genuine/NFI-02804028.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/README.txt.txt
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00503015.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00401024.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02502010.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01104012.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00103030.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00101014.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01101016.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02304008.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00505022.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00103014.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00105028.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-03305006.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00104029.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02505009.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00105026.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00405024.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00402003.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00104014.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00104025.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00404013.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02503010.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00705011.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00403013.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00703023.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01102012.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00103019.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00704023.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00104027.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00404003.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00102025.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00102030.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01202021.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00402024.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02504010.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00401013.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02301008.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00405003.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-03303006.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-03302006.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00301009.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00405013.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00302009.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00103026.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01701020.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00304002.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00504022.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00302002.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-08803004.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00102028.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00304009.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00303001.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00305001.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00403007.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00103029.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-03304006.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02501010.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01303017.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00304001.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00702011.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00101029.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02305008.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00702023.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00105019.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00304018.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00105014.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-08805004.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00102029.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01305017.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00101019.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00302001.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00102014.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01103012.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00302018.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00301001.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00501015.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00705023.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00101027.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01201021.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00301018.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01105012.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00401003.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00101028.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01703020.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-08802004.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01301017.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01102016.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00302005.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-03301006.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00103025.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00104028.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01702020.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00501022.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00701023.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00105030.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00504015.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02306008.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01205021.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00105027.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-08801004.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00703011.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00403024.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00404024.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00305002.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01704020.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00301005.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00305005.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00102027.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00104030.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-08804004.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00101026.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01103016.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00503022.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01101012.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01705020.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01203021.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00105029.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00505015.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00301002.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00105025.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00104019.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00304005.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00101025.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00403003.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00303002.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00502022.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00103027.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00401007.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00303009.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00101030.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00405007.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01104016.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00102019.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00704011.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01105016.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00502015.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00305009.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01302017.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00303005.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00104026.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00305018.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-02303008.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00402007.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00701011.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01204021.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-01304017.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00404007.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00303018.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00103028.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00402013.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/forged/NFI-00102026.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01104011.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00101001.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00504005.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00801008.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01103011.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00405004.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01102011.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00305003.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00803008.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01903019.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02705027.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00203002.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01601016.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00505005.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01405014.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01604016.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01301013.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01801018.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02401024.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01002010.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02904029.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01001010.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02304023.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01704017.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01702017.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00901009.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02901029.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02103021.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01204012.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02903029.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02703027.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02202022.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01502015.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02302023.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01504015.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01202012.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00903009.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00804008.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01105011.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00604006.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02604026.PNG
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01005010.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00702007.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00701007.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00303003.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00304003.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-02105021.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01404014.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-01901019.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00605006.png
# /kaggle/input/handwritten-signatures/sample_signature/sample_Signature/genuine/NFI-00502005.png
# ...
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_46_18.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_46_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_43_2.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_20_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_22_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_32_11.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_32_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_21_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_55_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_20_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_29_21.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_34_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_9_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_4_13.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_33_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_42_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_54_3.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_40_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_4_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_25_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_30_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_53_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_53_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_4_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_9_22.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_28_3.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_38_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_12_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_17_5.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_10_14.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_8_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_55_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_51_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_53_15.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_33_2.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_38_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_39_5.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_30_21.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_36_18.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_55_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_31_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_55_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_27_11.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_48_18.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_31_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_9_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_6_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_42_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_40_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_10_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_8_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_17_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_13_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_42_2.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_40_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_12_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_5_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_53_14.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_18_13.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_3_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_29_5.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_36_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_5_5.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_34_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_36_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_34_23.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_26_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_41_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_49_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_7_14.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_13_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_38_13.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_6_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_52_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_36_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_11_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_36_5.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_36_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_49_22.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_51_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_40_2.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_45_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_24_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_8_13.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_13_21.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_41_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_17_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_2_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_19_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_3_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_34_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_29_14.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_22_3.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_24_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_30_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_54_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_17_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_6_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_40_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_23_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_18_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_5_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_11_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_44_21.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_2_21.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_48_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_1_5.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_52_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_35_11.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_13_15.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_32_3.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_40_22.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_4_21.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_21_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_41_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_35_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_11_18.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_25_15.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_21_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_34_2.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_24_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_42_21.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_37_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_1_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_3_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_48_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_52_2.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_23_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_15_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_6_14.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_48_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_32_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_43_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_52_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_49_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_50_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_39_23.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_28_23.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_21_23.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_4_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_30_13.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_11_11.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_48_22.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_3_5.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_2_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_55_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_4_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_50_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_15_11.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_50_21.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_28_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_19_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_9_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_34_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_43_15.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_35_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_9_23.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_1_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_24_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_10_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_34_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_17_22.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_33_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_54_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_46_13.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_23_3.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_34_14.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_14_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_51_13.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_35_2.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_53_13.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_48_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_27_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_25_14.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_12_23.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_9_3.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_54_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_33_1.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_42_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_16_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_44_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_46_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_12_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_23_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_12_2.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_17_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_29_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_51_7.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_24_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_39_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_25_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_53_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_19_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_10_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_34_3.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_40_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_16_11.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_33_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_42_3.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_39_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_10_22.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_24_23.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_3_21.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_15_23.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_46_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_27_19.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_54_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_50_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_12_13.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_50_22.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_33_16.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_12_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_6_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_21_24.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_50_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_51_11.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_40_6.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_14_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_33_12.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_41_22.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_54_5.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_28_8.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_46_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_21_9.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_41_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_42_17.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_18_15.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_9_15.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_19_20.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_14_4.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_54_10.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_2_15.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_31_2.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_30_14.png
# /kaggle/input/cedardataset/signatures/full_forg/forgeries_4_24.png
# /kaggle/input/icdar2011signatureverification/sigComp2011-test.zip
# /kaggle/input/icdar2011signatureverification/sigComp2011-trainingSet.zip

# %%
import numpy as np
from keras import layers
from keras.layers import Input, Add, Multiply, Subtract, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, Dropout, MaxPooling2D, GlobalMaxPooling2D
from keras.layers import Dense, Dropout, Input, Lambda, Flatten, Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.regularizers import l2
from keras.models import Model, load_model, Sequential
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
# from keras.utils import plot_model
#from resnets_utils import *
from keras.initializers import glorot_uniform, he_normal
import scipy.misc
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline
import keras.backend as K
K.set_image_data_format('channels_last') 
# K.set_learning_phase(1) 
import scipy
import cv2
from keras.layers import subtract
import keras
from keras.layers import Lambda
import tensorflow as tf 
from tensorflow.keras.optimizers import Adam,RMSprop

# %%
from tensorflow import image
from tensorflow.keras.utils import *

# %%
from PIL import Image,ImageOps

# %%
SIZE=(220,155)

# %%
import os
img_path='../input/cedardataset/signatures/full_org/original_11_17.png'

# %%
def preprocess(img_input):
    img_input=cv2.resize(img_input,SIZE,interpolation=cv2.INTER_LINEAR )
#     img_input=cv2.bitwise_not(img_input)
    img_input=img_input/245
    return img_input

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
img = load_img(img_path,target_size=(155,220)) 
x = img_to_array(img)
x=preprocess(x)

# %%
x.shape
# Out:
# (155, 220, 3)

# %%
from matplotlib.pyplot import imshow

# %%
imshow(x)

# %%
import os
img_path='../input/cedardataset/signatures/full_org/original_11_17.png'

# %%
img = load_img(img_path,target_size=(155,220)) 
x = img_to_array(img)
x=preprocess(x)

# %%
x.shape
# Out:
# (155, 220, 3)

# %%
from matplotlib.pyplot import imshow

# %%
imshow(x)

# %%
def euclidian(vects):
    X,y=vects
    return K.sqrt(K.sum(K.square(X-y),axis=1,keepdims=True))

def euclidean_distance_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
def contrastive_loss(y, preds, margin=1):
	# explicitly cast the true class label data type to the predicted
	# class label data type (otherwise we run the risk of having two
	# separate data types, causing TensorFlow to error out)
	y = tf.cast(y, preds.dtype)
	# calculate the contrastive loss between the true labels and
	# the predicted labels
	squaredPreds = K.square(preds)
	squaredMargin = K.square(K.maximum(margin - preds, 0))
	loss = K.mean(y * squaredPreds + (1 - y) * squaredMargin)
	# return the computed contrastive loss to the calling function
	return loss

# %%
input_shape=(155,230,3)

# %%
def siamese(input_shape):
    model=Sequential()
    model.add(Conv2D(96, (11,11), activation='relu', name='conv11',input_shape=input_shape))
    model.add(BatchNormalization(epsilon=1e-06,  axis=1, momentum=0.9))
    model.add(MaxPooling2D((3,3), strides=(2, 2),padding='same'))    


    model.add(Conv2D(256, (5,5), activation='relu', name='conv12'))
    model.add(BatchNormalization(epsilon=1e-06,  axis=1, momentum=0.9))
    model.add(MaxPooling2D((3,3), strides=(2, 2),padding='same'))    
    model.add(Dropout(0.3))

    model.add(Conv2D(384, (3,3), activation='relu', name='conv13',input_shape=input_shape,padding='same'))
    model.add(Conv2D(256, (3,3), activation='relu', name='conv14'))
    model.add(MaxPooling2D((3,3), strides=(2, 2),padding='same'))
    model.add(Flatten())
    model.add(Dense(1024, kernel_regularizer=l2(0.0005), activation='relu', kernel_initializer=glorot_uniform(seed=0)))
    model.add(Dropout(0.3))
    model.add(Dense(128, kernel_regularizer=l2(0.0005), activation='relu', kernel_initializer=glorot_uniform(seed=0)))
    return model

# %%
apply_sigmodel = siamese((155,220,3))
    
X_input1 = Input(shape=(155,220,3))
X_input2 = Input(shape=(155,220,3)) 

X_vect1 = apply_sigmodel(X_input1)
X_vect2 = apply_sigmodel(X_input2)
    
distance = Lambda(euclidian, output_shape=euclidean_distance_output_shape)([X_vect1,X_vect2])
    
model = Model(inputs=[X_input1,X_input2], outputs=distance)

# %%
rms = RMSprop(learning_rate=1e-4, rho=0.9, epsilon=1e-08)

# %%
model.compile(loss=contrastive_loss,optimizer=rms,metrics=['accuracy'])

# %%
forg_list_1=[]
for i in range(20):
    p=[]
    for j in range(24):
        img_path = '../input/cedardataset/signatures/full_forg/forgeries_'+str(i+1) +'_' +str(j+1)+'.png'
        img = load_img(img_path,target_size=(155,220)) 
        x = img_to_array(img)
        x=preprocess(x)
        p.append(x)
    forg_list_1.append(p)

# %%
org_list_1=[]
for i in range(20):
    p=[]
    for j in range(24):
        img_path = '../input/cedardataset/signatures/full_org/original_'+str(i+1) +'_' +str(j+1)+'.png'
        img = load_img(img_path,target_size=(155,220)) 
        x = img_to_array(img)
        x=preprocess(x)
        p.append(x)
    org_list_1.append(p)

# %%
X_train1=[]
X_train2=[]
for i in range(10):
    count=24
    while(count>1):
        for j in range(0,count-1):
            X_train1.append(org_list_1[i][24-count])
            X_train2.append(org_list_1[i][24-count+j+1])
        count=count-1
       
for i in range(10):
    count=24
    while(count>1):
        for j in range(0,count-1):
            X_train1.append(org_list_1[i][24-count])
            X_train2.append(forg_list_1[i][24-count+j+1])
        count=count-1

# %%
len(X_train1)
# Out:
# 5520

# %%
X_train1=np.asarray(X_train1)
X_train2=np.asarray(X_train2)

# %%
12420
# Out:
# 12420

# %%
Y_train=np.array([])
for m in range(2760):
    Y_train=np.insert(Y_train,0,1)
for n in range(2760):
    Y_train=np.insert(Y_train,0,0)

# %%
model.fit([X_train1,X_train2], Y_train, epochs = 5, batch_size = 10)
# Out:
# Epoch 1/5
# 552/552 [==============================] - 88s 160ms/step - loss: 3.7764 - accuracy: 0.5013
# Epoch 2/5
# 552/552 [==============================] - 88s 159ms/step - loss: 0.3070 - accuracy: 0.5042
# Epoch 3/5
# 552/552 [==============================] - 88s 159ms/step - loss: 0.2738 - accuracy: 0.4842
# Epoch 4/5
# 552/552 [==============================] - 88s 159ms/step - loss: 0.2537 - accuracy: 0.3960
# Epoch 5/5
# 552/552 [==============================] - 88s 159ms/step - loss: 0.2128 - accuracy: 0.3024

# %%
import h5py
model.save_weights('model_weights33.h5')

# %%
del X_train1, X_train2

# %%
img_1=load_img('../input/cedardataset/signatures/full_forg/forgeries_20_10.png',target_size=(155,220)) 
x = img_to_array(img_1)
x=preprocess(x)
l1=[x]
# l2=[x2]
l1=np.asarray(l1)
# l2=np.asarray(l2)

# %%
l1=[x]
# l2=[x2]
l1=np.asarray(l1)

# %%
img_1=load_img('../input/cedardataset/signatures/full_org/original_20_10.png',target_size=(155,220)) 
x = img_to_array(img_1)
x=preprocess(x)

# %%
l2=[x]
l2=np.asarray(l2)

# %%
pred=model.predict([l1,l2])

# %%
pred
# Out:
# array([[2.071154]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score

# get predictions on test data
pred = model.predict([l1, l2])
pred = pred.reshape(-1)  # flatten to a 1D array

# convert distances to similarities
similarity = 1/(1+pred)

# set a threshold to convert similarities to class predictions
threshold = 0.5
predictions = (similarity > threshold).astype(int)

# calculate accuracy
y_true = [0]  # replace with the actual labels of the samples
accuracy = accuracy_score(y_true, predictions)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 1.0
